# %%
! python get_results_UDA.py --augmentation none --dataset office_home
# Out:
# Namespace(T=30, alpha0=0.4, alpha1T=0.1, augmentation='none', beta0=0.2, beta1T=0.05, dataset='office_home', eta0=40, eta1T=80, gamma1T=0.9, save_weights=False, taus1T=0.8, tautu110=0.9, tautu1120=0.8, tautu2130=0.7)
# convnext_xlarge_384_in22ft1k
# CORAL alignment ...
# Train classifier on labeled ...
# (78.09851169586182, 99.56392049789429, 0.0)
# 5 ites of self-training ...
# (81.71821236610413, 98.87537360191345, 0.0)
# 5 ites of self-training ...
# (82.03895092010498, 98.59995245933533, 0.0)
# 5 ites of self-training ...
# (82.03895092010498, 98.96717667579651, 0.0)
# 5 ites of self-training ...
# (81.87857866287231, 98.78356456756592, 0.0)
# 5 ites of self-training ...
# (81.71821236610413, 98.82946610450745, 0.0)
# 5 ites of self-training ...
# (81.83276057243347, 98.92127513885498, 0.0)
# CORAL alignment ...
# Train classifier on labeled ...
# (92.61094927787781, 99.51801300048828, 0.0)
# 5 ites of self-training ...
# (94.95381712913513, 98.59995245933533, 0.0)
# ...

# %%
! python get_results_UDA.py --augmentation none --dataset office_home --T 30 --eta0 40 --eta1T 80 --alpha0 0.4 --beta0 0.2 --alpha1T 0.1 --beta1T 0.05 --gamma1T 0.9 --taus1T 0.8 --tautu110 0.9 --tautu1120 0.8 --tautu2130 0.7
# Out:
# Namespace(T=30, alpha0=0.4, alpha1T=0.1, augmentation='none', beta0=0.2, beta1T=0.05, dataset='office_home', eta0=40.0, eta1T=80.0, gamma1T=0.9, save_weights=False, taus1T=0.8, tautu110=0.9, tautu1120=0.8, tautu2130=0.7)
# convnext_xlarge_384_in22ft1k
# CORAL alignment ...
# ^C

# %%
! python get_results_large_UDA.py
# Out:
# Namespace(dataset='office_home')
# ...
# Ask each 4x7 enasemble members to vote. Majority wins.
# ...
# R->C, R->P, R->A, P->R, P->C, P->A, A->P, A->C, A->R, C->R, C->A, C->P,
# 85.45246124267578, 95.17909288406372, 90.1524543762207, 94.72113847732544, 82.93241858482361, 89.45199847221375, 93.73732805252075, 83.52806568145752, 94.33096051216125, 94.35391426086426, 90.64688682556152, 93.44446659088135,
#
# ...
# Average prediction over 4 x 7 models.
# ...
# R->C, R->P, R->A, P->R, P->C, P->A, A->P, A->C, A->R, C->R, C->A, C->P,
# 85.58992147445679, 95.17909288406372, 90.19365310668945, 94.69818472862244, 82.97823667526245, 89.20478224754333, 94.00765895843506, 83.64261388778687, 94.35391426086426, 94.28505897521973, 90.7705008983612, 93.73732805252075,
